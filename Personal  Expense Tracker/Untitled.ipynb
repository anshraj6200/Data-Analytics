# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")  # Optional: Seaborn style

# %%
# Using seaborn's version (easiest)
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df = titanic[['survived', 'sex', 'age', 'class']]  # 'class' = ticket class
df.dropna(subset=['age'], inplace=True)  # remove missing ages
df.head()
# Out:
# C:\Users\anshr\AppData\Local\Temp\ipykernel_5060\3624944645.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['age'], inplace=True)  # remove missing ages
#    survived     sex   age  class
# 0         0    male  22.0  Third
# 1         1  female  38.0  First
# 2         1  female  26.0  Third
# 3         1  female  35.0  First
# 4         0    male  35.0  Third

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='survived', data=df)
plt.title('Survived vs Not Survived')
plt.xticks([0, 1], ['Not Survived', 'Survived'])
plt.ylabel('Number of Passengers')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='sex', y='survived', hue='class', data=df)
plt.title('Survival Rate by Gender and Class')
plt.ylabel('Survival Rate')
plt.show()

# %%
class_counts = df['class'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Passenger Class Distribution')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.show()
